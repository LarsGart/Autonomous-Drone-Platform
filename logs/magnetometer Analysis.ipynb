# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'cleanedMagData.txt',names=['C1','C2','C3','C4','C5','C6'],sep=',')

# %%
df['C1'] = df['C1'].str.replace('(','').astype(float)
df['C3'] = df['C3'].str.replace(')','').astype(float)
df['C4'] = df['C4'].str.replace('(','').astype(float)
df['C6'] = df['C6'].str.replace(')','').astype(float)
# Out:
# <ipython-input-3-8ce3a5614268>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['C1'] = df['C1'].str.replace('(','').astype(float)
# <ipython-input-3-8ce3a5614268>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['C3'] = df['C3'].str.replace(')','').astype(float)
# <ipython-input-3-8ce3a5614268>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['C4'] = df['C4'].str.replace('(','').astype(float)
# ...

# %%
df
# Out:
#        C1     C2     C3    C4     C5     C6
# 0   -3.39 -20.64  39.20 -67.9 -101.6  107.9
# 1   -2.71 -20.96  40.63 -67.2 -101.9  109.3
# 2   -3.20 -21.24  39.92 -67.7 -102.2  108.6
# 3   -3.61 -20.76  41.46 -68.1 -101.7  110.1
# 4   -3.41 -20.56  40.74 -67.9 -101.5  109.4
# ..    ...    ...    ...   ...    ...    ...
# 196 -1.25 -20.50  42.98 -65.7 -101.4  111.6
# 197 -0.23 -20.48  39.79 -64.7 -101.4  108.5
# 198 -0.44 -19.30  40.50 -64.9 -100.2  109.2
# 199 -0.63 -20.48  40.61 -65.1 -101.4  109.3
# 200 -0.04 -20.19  40.40 -64.5 -101.1  109.1
#
# [201 rows x 6 columns]

# %%
df.C1.hist(bins=70)
df.C4.hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
df.hist(bins=40, figsize=(25,20))
plt.show()

# %%
import seaborn as sn
from matplotlib.pyplot import figure
figure(figsize=(15, 12))
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df.C1,df.C2,df.C3);

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df.C4,df.C5,df.C6);

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df.C1,df.C2,df.C3);
ax.scatter3D(df.C4,df.C5,df.C6);

# %%
! pip install plotly

# %%
# Import dependencies
import plotly
import plotly.graph_objs as go

# Configure Plotly to be rendered inline in the notebook.
plotly.offline.init_notebook_mode()

# Configure the trace.
trace = go.Scatter3d(
    x=df.C1,  # <-- Put your data instead
    y=df.C2,  # <-- Put your data instead
    z=df.C3,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 10,
        'opacity': 0.8,
    }
)

# Configure the layout.
layout = go.Layout(
    margin={'l': 0, 'r': 0, 'b': 0, 't': 0}
)

data = [trace]

plot_figure = go.Figure(data=data, layout=layout)

# Render the plot.
plotly.offline.iplot(plot_figure)

# %%
# Import dependencies
import plotly
import plotly.graph_objs as go

# Configure Plotly to be rendered inline in the notebook.
plotly.offline.init_notebook_mode()

# Configure the trace.
trace = go.Scatter3d(
    x=df.C4,  # <-- Put your data instead
    y=df.C5,  # <-- Put your data instead
    z=df.C6,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 10,
        'opacity': 0.8,
    }
)

# Configure the layout.
layout = go.Layout(
    margin={'l': 0, 'r': 0, 'b': 0, 't': 0}
)

data = [trace]

plot_figure = go.Figure(data=data, layout=layout)

# Render the plot.
plotly.offline.iplot(plot_figure)
